# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from model.arima import ARIMA_MODEL

# %%
df = pd.read_csv("D:/Travel Time Prediction/cleandata/start_stop/2.csv",parse_dates=["datetime"])

# %%
df
# Out:
#                 datetime       delta_t  day_of_week
# 0    2019-01-01 00:00:00  18899.000000          1.0
# 1    2019-01-01 01:00:00  18899.000000          1.0
# 2    2019-01-01 02:00:00  18899.000000          1.0
# 3    2019-01-01 03:00:00  18899.000000          1.0
# 4    2019-01-01 04:00:00  20205.333333          1.0
# ...                  ...           ...          ...
# 7408 2019-12-31 16:00:00  12971.000000          1.0
# 7409 2019-12-31 17:00:00  17940.000000          1.0
# 7410 2019-12-31 18:00:00  12882.000000          1.0
# 7411 2019-12-31 19:00:00  12882.000000          1.0
# 7412 2019-12-31 20:00:00  12882.000000          1.0
#
# [7413 rows x 3 columns]

# %%
arima = ARIMA_MODEL(df)
arima.find_p()
arima.find_d()
arima.find_q()
# Out:
# p =  2
# p-value: 2.108426231497189e-28
# d = 0
# q= 9

# %%
arima.p = 9
arima.d = 0 
arima.q = 8
arima.train_model()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
arima.grid_search()
# Out:
# Order = (0, 0, 0)
# AIC = 86974.23118115574
# Order = (0, 0, 1)
# AIC = 86219.7675278089
# Order = (0, 0, 2)
# AIC = 85972.6052487148
# Order = (0, 0, 3)
# AIC = 85921.46343867786
# Order = (0, 0, 4)
# AIC = 85880.49722293357
# Order = (0, 0, 5)
# AIC = 85877.59995605994
# Order = (0, 0, 6)
# AIC = 85869.23314401516
# Order = (0, 0, 7)
# AIC = 85865.25805735696
# Order = (0, 0, 8)
# AIC = 85862.81837645514
# Order = (0, 0, 11)
# AIC = 85859.92262513252
# Order = (1, 0, 1)
# AIC = 85857.87098937784
# Order = (1, 0, 3)
# AIC = 85855.29947525111
# Order = (3, 0, 2)
# AIC = 85854.0795680077
# Order = (5, 0, 4)
# AIC = 85853.76264902059
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# Order = (5, 0, 5)
# AIC = 85824.14581596563
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# Order = (6, 0, 3)
# AIC = 85744.89700329956
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# Order = (7, 0, 7)
# AIC = 85741.42004253715
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# Order = (8, 0, 7)
# AIC = 85731.57937834936
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# Order = (9, 0, 3)
# AIC = 85719.6512739748
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Order = (9, 0, 8)
# AIC = 85718.81479925246
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
arima.test_model()
# Out:
# MSE = 22356818.328927178
# MAE = 3497.2499210093933

# %%
test = df[df["datetime"] >= "2019-08-10"].reset_index(drop=True)
test
# Out:
#                 datetime       delta_t  day_of_week
# 0    2019-08-10 00:00:00  16980.513953          5.0
# 1    2019-08-10 01:00:00  16971.908527          5.0
# 2    2019-08-10 02:00:00  16963.303101          5.0
# 3    2019-08-10 03:00:00  16954.697674          5.0
# 4    2019-08-10 04:00:00  16946.092248          5.0
# ...                  ...           ...          ...
# 3019 2019-12-31 16:00:00  15715.250000          1.0
# 3020 2019-12-31 17:00:00  15271.666667          1.0
# 3021 2019-12-31 18:00:00  16805.000000          1.0
# 3022 2019-12-31 19:00:00  16805.000000          1.0
# 3023 2019-12-31 20:00:00  16805.000000          1.0
#
# [3024 rows x 3 columns]

# %%
arima.test
# Out:
#                 datetime       delta_t  day_of_week
# 0    2019-08-10 00:00:00  16980.513953          5.0
# 1    2019-08-10 01:00:00  16971.908527          5.0
# 2    2019-08-10 02:00:00  16963.303101          5.0
# 3    2019-08-10 03:00:00  16954.697674          5.0
# 4    2019-08-10 04:00:00  16946.092248          5.0
# ...                  ...           ...          ...
# 3019 2019-12-31 16:00:00  15715.250000          1.0
# 3020 2019-12-31 17:00:00  15271.666667          1.0
# 3021 2019-12-31 18:00:00  16805.000000          1.0
# 3022 2019-12-31 19:00:00  16805.000000          1.0
# 3023 2019-12-31 20:00:00  16805.000000          1.0
#
# [3024 rows x 3 columns]
