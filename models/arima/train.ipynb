# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from model.arima import ARIMA_MODEL

# %%
df = pd.read_csv("D:/Travel Time Prediction/cleandata/start_stop/1.csv",parse_dates=["datetime"])

# %%
df
# Out:
#                 datetime       delta_t  day_of_week
# 0    2019-01-01 00:00:00  15034.000000          1.0
# 1    2019-01-01 01:00:00  17934.000000          1.0
# 2    2019-01-01 02:00:00  17211.333333          1.0
# 3    2019-01-01 03:00:00  16488.666667          1.0
# 4    2019-01-01 04:00:00  16258.000000          1.0
# ...                  ...           ...          ...
# 7408 2019-12-31 16:00:00  15715.250000          1.0
# 7409 2019-12-31 17:00:00  15271.666667          1.0
# 7410 2019-12-31 18:00:00  16805.000000          1.0
# 7411 2019-12-31 19:00:00  16805.000000          1.0
# 7412 2019-12-31 20:00:00  16805.000000          1.0
#
# [7413 rows x 3 columns]

# %%
arima = ARIMA_MODEL(df)
arima.find_p()
arima.find_d()
arima.find_q()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py:1024: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs // 2 - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# p =  7
# p-value: 1.5289993781854867e-28
# d = 0
# q= 12
# D:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(

# %%
arima.train_model()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
arima.test_model()
# Out:
# MSE = 7935062.837998483
# MAE = 2071.8563236109394

# %%
results = arima.get_model()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                delta_t   No. Observations:                 4389
# Model:                    ARMA(7, 12)   Log Likelihood              -40745.494
# Method:                       css-mle   S.D. of innovations           2601.985
# Date:                Thu, 07 Oct 2021   AIC                          81532.988
# Time:                        18:06:00   BIC                          81667.112
# Sample:                             0   HQIC                         81580.307
#
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.584e+04     97.692    162.091      0.000    1.56e+04     1.6e+04
# ar.L1.delta_t      0.0888      0.040      2.233      0.026       0.011       0.167
# ...

# %%
test = df[df["datetime"] >= "2019-08-10"].reset_index(drop=True)
test
# Out:
#                 datetime       delta_t  day_of_week
# 0    2019-08-10 00:00:00  16980.513953          5.0
# 1    2019-08-10 01:00:00  16971.908527          5.0
# 2    2019-08-10 02:00:00  16963.303101          5.0
# 3    2019-08-10 03:00:00  16954.697674          5.0
# 4    2019-08-10 04:00:00  16946.092248          5.0
# ...                  ...           ...          ...
# 3019 2019-12-31 16:00:00  15715.250000          1.0
# 3020 2019-12-31 17:00:00  15271.666667          1.0
# 3021 2019-12-31 18:00:00  16805.000000          1.0
# 3022 2019-12-31 19:00:00  16805.000000          1.0
# 3023 2019-12-31 20:00:00  16805.000000          1.0
#
# [3024 rows x 3 columns]

# %%
arima.test
# Out:
#                 datetime       delta_t  day_of_week
# 0    2019-08-10 00:00:00  16980.513953          5.0
# 1    2019-08-10 01:00:00  16971.908527          5.0
# 2    2019-08-10 02:00:00  16963.303101          5.0
# 3    2019-08-10 03:00:00  16954.697674          5.0
# 4    2019-08-10 04:00:00  16946.092248          5.0
# ...                  ...           ...          ...
# 3019 2019-12-31 16:00:00  15715.250000          1.0
# 3020 2019-12-31 17:00:00  15271.666667          1.0
# 3021 2019-12-31 18:00:00  16805.000000          1.0
# 3022 2019-12-31 19:00:00  16805.000000          1.0
# 3023 2019-12-31 20:00:00  16805.000000          1.0
#
# [3024 rows x 3 columns]
